# %% [markdown]
# # SCRAPING AMAZON BOOK DATA

# %% [markdown]
# ## Importing Useful Libraries

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## Getting Genre data

# %%
r = requests.get("https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_unv_books_1_1318158031_2")
# Convert to a beautiful soup object
soup = bs(r.content)
# Print out the HTML
contents = soup.prettify()

# %% [markdown]
# - Getting genre name and their website URL's

# %%
info_box = soup.find(class_='_p13n-zg-nav-tree-all_style_zg-browse-group__88fbz')
info_rows = info_box.find_all("a")
info_dict ={}
base_path = 'https://www.amazon.in'
for row in info_rows:
    relative_path = row['href']
    full_path= base_path + relative_path 
    title = list(row)[0]
    info_dict[title] = full_path

# %% [markdown]
# ### Getting Adventure Genre Book Info

# %%
r = requests.get("https://www.amazon.in/gp/bestsellers/books/1318158031")

# Convert to a beautiful soup object
soupb = bs(r.content)

# Print out the HTML
contents = soupb.prettify()

# %%
book_info = soupb.find_all(class_='_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y')
book_dict = {}
book_name=[]
author = []
for index,row in enumerate(book_info):
    title = list(row)[0]
    if index==0 or index%2==0:
        book_name.append(title)
    else:
        author.append(title)
# Out:
# 50

# %% [markdown]
# -- Finding ratings and remaining data according to our structure

# %%
#ratings
ratings = soupb.find_all(class_ = 'a-icon-alt')
book_rating = []
for row in ratings:
    rating = list(row)[0].split()[0]
    book_rating.append(float(rating))
# Out:
# [4.7,
#  4.3,
#  4.5,
#  4.2,
#  4.5,
#  4.3,
#  4.5,
#  4.6,
#  4.5,
#  4.6,
#  4.3,
#  4.3,
#  4.5,
#  4.4,
#  4.4,
#  4.3,
#  4.7,
#  4.6,
#  4.4,
#  4.3,
#  4.4,
#  4.3,
#  4.7,
#  4.7,
#  4.7,
#  4.7,
#  4.7,
#  4.5,
#  4.6,
#  4.4,
#  4.6,
#  4.7,
#  4.7,
#  4.6,
#  4.2,
#  4.4,
#  4.4,
#  4.5,
#  4.4,
#  4.4,
#  4.6,
#  4.8,
#  4.4,
#  4.4,
#  4.5,
#  4.8,
#  4.7,
#  4.3,
#  4.6,
#  4.4]

# %%
#no of reviews
reviews = soupb.find_all(class_ = "a-size-small")
book_no_of_reviews= []
text_list=[]
for index,row in enumerate(reviews):
    rating = list(row)[0].text
    text_list.append(rating)

i=2
for index,element in enumerate(text_list):
    if index==i:
        book_no_of_reviews.append(element)
        i=i+5
    
book_no_of_reviews = book_no_of_reviews[0:50]
# Out:
# 50

# %%
#publish_type
publish_type = soupb.find_all(class_ = "a-size-small a-color-secondary a-text-normal")
book_publish_type= []
for row in publish_type:
    publish = list(row)[-1]
    book_publish_type.append(publish)
# Out:
# 50

# %%
#price
price = soupb.find_all(class_ = "p13n-sc-price")
price_list=[]
for row in price:
    price = list(row)[0]
    price_list.append(price)
# Out:
# 50

# %%
df = pd.DataFrame(list(zip(book_name, author,book_rating,book_no_of_reviews,book_publish_type,price_list)),
               columns =['book_name', 'author','book_rating','book_no_of_reviews','book_publish_type','price'])
df.head(5)
# Out:
#                                            book_name              author  \
# 0           Harry Potter and the Philosopher's Stone        J.K. Rowling
# 1           War of Lanka (Ram Chandra Series Book 4)      Amish Tripathi
# 2             The Complete Novels of Sherlock Holmes  Arthur Conan Doyle
# 3      Maalai Pozhuthin Mayakkathile (Tamil Edition)        Sashi Murali
# 4  Samsara: Enter the Valley of the Gods ("India'...        Saksham Garg
#
#    book_rating book_no_of_reviews book_publish_type    price
# 0          4.7             55,323    Kindle Edition  ₹284.05
# 1          4.3              2,299         Paperback  ₹352.00
# 2          4.5             15,471         Paperback  ₹139.00
# 3          4.2                 55    Kindle Edition  ₹409.00
# 4          4.5                326         Paperback  ₹150.00

# %% [markdown]
# ### Now Making Function for extracting book info of all genre

# %%
result = []
df_dict ={}
def book_info():
    for itm in info_dict.items():
        r = requests.get(itm[1])
        # Convert to a beautiful soup object
        soup = bs(r.content)
        # Print out the HTML
        contents = soup.prettify()

        book_info = soup.find_all(class_='_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y')
        book_dict = {}
        book_name=[]
        author = []
        for index,row in enumerate(book_info):
            title = list(row)[0]
            if index==0 or index%2==0:
                book_name.append(title)
            else:
                author.append(title)

        #ratings
        ratings = soup.find_all(class_ = 'a-icon-alt')
        book_rating = []
        for row in ratings:
            rating = list(row)[0].split()[0]
            book_rating.append(float(rating))

        #no of reviews
        reviews = soup.find_all(class_ = "a-size-small")
        book_no_of_reviews= []
        text_list=[]
        for index,row in enumerate(reviews):
            rating = list(row)[0].text
            text_list.append(rating)
        i=2
        for index,element in enumerate(text_list):
            if index==i:
                book_no_of_reviews.append(element)
                i=i+5
        book_no_of_reviews = book_no_of_reviews[0:len(author)]

        #publish_type
        publish_type = soup.find_all(class_ = "a-size-small a-color-secondary a-text-normal")
        book_publish_type= []
        for row in publish_type:
            publish = list(row)[-1]
            book_publish_type.append(publish)

        #price
        price = soup.find_all(class_ = "p13n-sc-price")
        price_list=[]
        for row in price:
            price = list(row)[0]
            price_list.append(price)

        
        genre_list=[]
        for j in range(len(author)):
            genre_list.append(itm[0])
        
        df = pd.DataFrame(list(zip(genre_list,book_name, author,book_rating,book_no_of_reviews,book_publish_type,price_list)),
                   columns =['Genre','book_name', 'author','book_rating','book_no_of_reviews','book_publish_type','price'])
   
        df_dict[itm[0]] = df
    
    # Joining all dataframes
   
    for i in df_dict.values():
        result.append(i)
    global final_result
    final_result=pd.concat(result)
    
    return final_result

# %%
book_info()
# Out:
#                  Genre                                          book_name  \
# 0   Action & Adventure           Harry Potter and the Philosopher's Stone
# 1   Action & Adventure           War of Lanka (Ram Chandra Series Book 4)
# 2   Action & Adventure             The Complete Novels of Sherlock Holmes
# 3   Action & Adventure      Maalai Pozhuthin Mayakkathile (Tamil Edition)
# 4   Action & Adventure  Samsara: Enter the Valley of the Gods ("India'...
# ..                 ...                                                ...
# 44              Travel                                      Vikrant Pande
# 45              Travel                                          Rooprashi
# 46              Travel                                          Shari Low
# 47              Travel                                         Manav Kaul
# 48              Travel                                     Michael Easter
#
#                                                author  book_rating  \
# 0                                        J.K. Rowling          4.7
# 1                                      Amish Tripathi          4.3
# 2                                  Arthur Conan Doyle          4.5
# 3                                        Sashi Murali          4.2
# 4                                        Saksham Garg          4.5
# ..                                                ...          ...
# 44  Our Non-fairy Tale Life (Order Now & Get Autho...          4.6
# 45  One Last Day of Summer: The BRAND NEW novel of...          4.5
# 46  Bahut Door, Kitna Door Hota Hai । बहुत दूर, कि...          4.5
# 47  The Comfort Crisis: Embrace Discomfort To Recl...          4.7
# 48  Into Thin Air: A Personal Account of the Evere...          4.6
#
#    book_no_of_reviews book_publish_type    price
# 0              55,323    Kindle Edition  ₹284.05
# 1               2,299         Paperback  ₹352.00
# 2              15,471         Paperback  ₹139.00
# 3                  55    Kindle Edition  ₹409.00
# 4                 326         Paperback  ₹150.00
# ..                ...               ...      ...
# 44          Hardcover         Hardcover  ₹470.00
# 45          Paperback         Paperback  ₹109.00
# 46     Kindle Edition    Kindle Edition   ₹68.25
# 47          Paperback         Paperback  ₹130.00
# 48     Kindle Edition    Kindle Edition  ₹404.28
#
# [1497 rows x 7 columns]

# %%
final_result['Genre'].value_counts()
# Out:
# Action & Adventure                       50
# Comics & Mangas                          50
# Reference                                50
# Humour                                   50
# Health, Fitness & Nutrition              49
# Textbooks & Study Guides                 49
# Sports                                   49
# Society & Social Sciences                49
# Science & Mathematics                    49
# School Books                             49
# History                                  49
# Travel                                   49
# Engineering                              49
# Fantasy, Horror & Science Fiction        49
# Biographies, Diaries & True Accounts     49
# Children's & Young Adult                 49
# Computing, Internet & Digital Media      49
# Crafts, Home & Lifestyle                 49
# Exam Preparation                         48
# Arts, Film & Photography                 48
# Literature & Fiction                     48
# Politics                                 48
# Sciences, Technology & Medicine          48
# Religion                                 48
# Higher Education Textbooks               47
# Romance                                  47
# Health, Family & Personal Development    47
# Maps & Atlases                           47
# Language, Linguistics & Writing          47
# Medicine & Health Sciences               44
# Law                                      44
# Name: Genre, dtype: int64

# %%
final_result.tail(50)
# Out:
#                        Genre  \
# 48  Textbooks & Study Guides
# 0                     Travel
# 1                     Travel
# 2                     Travel
# 3                     Travel
# 4                     Travel
# 5                     Travel
# 6                     Travel
# 7                     Travel
# 8                     Travel
# 9                     Travel
# 10                    Travel
# 11                    Travel
# 12                    Travel
# 13                    Travel
# 14                    Travel
# 15                    Travel
# 16                    Travel
# 17                    Travel
# 18                    Travel
# 19                    Travel
# 20                    Travel
# 21                    Travel
# 22                    Travel
# 23                    Travel
# 24                    Travel
# 25                    Travel
# 26                    Travel
# 27                    Travel
# 28                    Travel
# 29                    Travel
# 30                    Travel
# 31                    Travel
# 32                    Travel
# 33                    Travel
# 34                    Travel
# 35                    Travel
# 36                    Travel
# 37                    Travel
# 38                    Travel
# 39                    Travel
# 40                    Travel
# 41                    Travel
# 42                    Travel
# 43                    Travel
# 44                    Travel
# 45                    Travel
# 46                    Travel
# 47                    Travel
# 48                    Travel
#
#                                             book_name  \
# 48                            Xamidea Editorial Board
# 0   Twenty-One Nights in Paris: Escape to Paris wi...
# 1   Murder in Tuscany: The start of a BRAND NEW co...
# 2   Masala Lab: The Science of Indian Cooking: The...
# 3                    World Map - Laminated Both Sides
# 4   India Map (Laminated Both Sides ) - With New U...
# 5                       Zen: The Art of Simple Living
# 6   I Wish I Could Tell Her (Order now to get a si...
# 7     Where the Sun Never Sets (Signed by the author)
# 8              Normal People: One million copies sold
# 9                                     Robinson Crusoe
# 37                              Banaras City of Light          4.6
# 38  THE SHADOW OF THE WIND: THE CEMETERY OF FORGOT...          4.5
# 39  Someone Else's Honeymoon: A laugh-out-loud, fe...          4.4
# 40  Whose Samosa is it Anyway?: The Story of Where...          4.3
# 41  The Atlas of Beauty: Women of the World in 500...          4.7
# 42               Susegad: The Goan Art of Contentment          4.3
# 43  In The Footsteps Of Rama: Travels with the Ram...          4.5
# 44  Our Non-fairy Tale Life (Order Now & Get Autho...          4.6
# 45  One Last Day of Summer: The BRAND NEW novel of...          4.5
# 46  Bahut Door, Kitna Door Hota Hai । बहुत दूर, कि...          4.5
# 47  The Comfort Crisis: Embrace Discomfort To Recl...          4.7
# 48  Into Thin Air: A Personal Account of the Evere...          4.6
#
#    book_no_of_reviews  book_publish_type      price
# 48          Paperback          Paperback    ₹589.00
# 0                 223     Kindle Edition    ₹109.74
# 1                 464     Kindle Edition     ₹85.74
# 2               1,958          Paperback    ₹259.00
# 3               9,784         Wall Chart    ₹129.00
# 4               5,761             Poster    ₹129.00
# 5               2,431          Hardcover    ₹379.00
# 6                 321          Paperback    ₹140.00
# 7                 177          Paperback    ₹162.00
# 8              48,000          Paperback    ₹323.00
# 9               3,724          Paperback     ₹99.00
# 10                  2          Paperback    ₹185.00
# 11              1,425          Hardcover    ₹324.00
# 12              1,179          Paperback    ₹260.00
# 13              4,634          Paperback    ₹446.00
# 14              1,907     Kindle Edition    ₹154.46
# 15                229          Paperback    ₹259.00
# 16             10,980          Paperback    ₹374.00
# 17                609          Paperback    ₹361.34
# 18                815          Paperback  ₹1,188.96
# 19              5,119          Hardcover    ₹388.00
# 20                743          Hardcover    ₹241.00
# 21              6,564          Paperback    ₹389.00
# 22                662     Kindle Edition    ₹147.00
# 23              3,239          Paperback    ₹126.00
# 24                714     Kindle Edition     ₹40.95
# 25              4,591  Audible Audiobook  ₹2,088.00
# 26                945          Paperback    ₹298.00
# 27                992          Hardcover    ₹583.00
# 28              1,271     Kindle Edition    ₹283.00
# 29              2,114          Hardcover    ₹452.00
# 30          Hardcover          Hardcover    ₹655.00
# 31          Paperback          Paperback    ₹194.00
# 32          Paperback          Paperback    ₹259.00
# 33          Paperback          Paperback    ₹488.00
# 34          Paperback          Paperback    ₹324.00
# 35          Paperback          Paperback    ₹310.00
# 36          Paperback          Paperback    ₹154.00
# 37     Kindle Edition     Kindle Edition    ₹215.00
# 38          Paperback          Paperback    ₹361.34
# 39          Paperback          Paperback    ₹398.00
# 40     Kindle Edition     Kindle Edition     ₹50.68
# 41          Hardcover          Hardcover    ₹328.00
# 42          Hardcover          Hardcover    ₹500.00
# 43          Hardcover          Hardcover    ₹259.00
# 44          Hardcover          Hardcover    ₹470.00
# 45          Paperback          Paperback    ₹109.00
# 46     Kindle Edition     Kindle Edition     ₹68.25
# 47          Paperback          Paperback    ₹130.00
# 48     Kindle Edition     Kindle Edition    ₹404.28

# %%
final_result['book_no_of_reviews']
# Out:
# 0             55,323
# 1              2,299
# 2             15,471
# 3                 55
# 4                326
#            ...
# 44         Hardcover
# 45         Paperback
# 46    Kindle Edition
# 47         Paperback
# 48    Kindle Edition
#        '₹269.95', '₹433.00', '₹329.65', '₹142.00', '₹178.60', '₹268.00',
#        '₹109.25', '₹852.00', '₹142.78', '₹497.00', '₹167.00', '₹690.00',
#        '₹465.00', '₹114.00', '₹197.00', '₹201.02', '₹155.37', '₹467.00',
#        '₹127.13', '₹189.00', '₹724.00', '₹228.00', '₹76.00', '₹1,521.00',
#        '₹864.00', '₹932.00', '₹480.00', '₹395.00', '₹388.00', '₹391.00',
#        '₹1,445.00', '₹260.00', '₹240.95', '₹179.70', '₹313.00', '₹519.00',
#        '₹378.00', '₹196.00', '₹1,063.00', '₹153.32', '₹182.00', '₹405.00',
#        '₹568.94', '₹967.77', '₹703.00', '₹280.39', '₹347.00', '₹665.00',
#        '₹398.00', '₹265.06', '₹1,549.00', '₹1,340.06', '₹474.05',
#        '₹146.00', '₹181.00', '₹489.00', '₹512.00', '₹147.04', '₹345.05',
#        '₹711.00', '₹119.89', '₹127.71', '₹115.00', '₹86.00', '₹589.00',
#        '₹323.00', '₹185.00', '₹1,188.96', '₹241.00', '₹147.00', '₹40.95',
#        '₹2,088.00', '₹583.00', '₹283.00', '₹655.00', '₹488.00', '₹154.00',
#        '₹215.00', '₹50.68', '₹328.00', '₹470.00', '₹68.25', '₹404.28'],
#       dtype=object)

# %%
final_result['book_no_of_reviews'].unique()
# Out:
# array(['55,323', '2,299', '15,471', '55', '326', '874', '136', '12,673',
#        '136,687', '2,296', '191', '19', '464', '73', '438', '7,445',
#        '11,515', '627', '12,126', '35,843', '30,066', '4', '32,391',
#        '37,475', '8,233', '8,349', '1,617', '10,515', '42,480', '34,482',
#        '19,062', '177', '150', '3,724', '200', '5,932', '903', '8,472',
#        '46', '3,341', '16,754', '3,588', '7,806', '1,031', '214', '6,094',
#        '480', '1,314', '2,270', '5,968', '7,098', '2,537', '1,397', '17',
#        '409', '1,628', '4,061', '27,721', '41', '1,979', '1,323', '93',
#        '37', '343', '1,764', 'Spiral-bound', 'Paperback', 'Hardcover',
#        'Sheet music', 'G.K. Publications (P) Ltd.', 'Will Smith',
#        'Matthew McConaughey', 'P.G. Van', 'Dreamland Publications',
#        'Don Norman', 'Herge', "Commercial's Board of Editors",
#        'Irving Stone', 'Roshan Kumar  Chaudhary ', 'Adrian Newey', '1',
#        '50,788', '60,044', '253', '10,043', '5,766', '14,777', '81,892',
#        '8,305', '924', '7,756', '5,314', '8,679', '16,891', '1,712',
#        '726', '282', '3,561', '5,780', '24,476', '12,886', '40', '3,026',
#        'Kindle Edition', '121', '65,030', '2,313', '16,953', '5,999',
#        '89', '22,632', '1,861', '78', '2,529', '676', '7,633', '44,970',
#        '7,406', '1,153', '17,506', '70', '2,459', '102', '4,173', '68',
#        '10,748', '2,100', '777', '10,844', '3,806', '862', 'Board book',
#        '195', '688', '44', '62,801', '527', '119', '175', '82', '394',
#        '5,748', '653', '431', '126', '169', '5', '376', '876', '223',
#        '10', '45', '310', '54', '238', '669', '2,177', '3,770', '5,673',
#        '26', '15', '10,932', '4,475', '32', '28', '4,509', '1,276', '221',
#        '99', '2', '3', '25', '1,730', '21', '311', '554', '796', '1,638',
#        '1,194', '4,564', '8,709', 'Audible Audiobook', '2,888', '3,746',
#        '59', '46,682', '648', '3,587', '1,958', '1,434', '4,882', '3,119',
#        '2,223', '2,230', '8,394', '2,431', '258', '945', '321', '1,428',
#        '8,601', '732', '3,270', '1,163', '270', '125', '1,639', '452',
#        '3,497', '714', '1,251', '680', '868', '601', '52', '549',
#        'Wall Chart', 'Unknown Binding', '735', '2,872', '17,838',
#        'Product Bundle', 'Pinnacle Publications', 'PMF IAS', 'Shankar',
#        'R S Aggarwal', 'Arihant Experts', 'SP Bakshi', 'Manish Rannjan',
#        'Himanshi Singh', 'I E Irodov', 'Disha Experts', 'RAJIV AHIR',
#        'Balasaheb Shinde', 'ARUN SHARMA', 'Gagan Pratap Sir', '1,601',
#        '20,080', '69', '640', '936', '48,479', '22,689', '60,698',
#        '39,660', '44,349', '3,419', '651', '64,080', '14,460', '612',
#        'Robert T. Kiyosaki', 'Napoleon Hill', 'Yogesh Vermani',
#        'Héctor García', 'Sadhguru', 'Joseph Murphy', 'Dale Carnegie',
#        'Robin Sharma', 'Viktor E Frankl', 'Ankur Warikoo', '10,320',
#        'Stephen Hawking', 'CHAURASIA B.D.', 'Educart',
#        'Anil Yadav/अनिल यादव', '51,893', '3,300', '13,822', '3,022',
#        '4,661', '1,201', '6,921', '1,131', '55,171', '2,448', '20,290',
#        '4,399', '138', '411', '34', '1,383', '31', '20', '64', '272',
#        '1,327', '30', '686', '839', '43', '747', '3,084', '587', '86',
#        '17,110', '84,709', '2,852', '504', '4,085', '12,653', '6,972',
#        '3,910', '131', '157', '2,011', '2,242', '194', '2,388', '2,209',
#        '3,883', '16', '3,254', '2,941', '2,092', '3,589', '405', '1,705',
#        '2,319', '623', '332', '2,133', '224', '3,045', '1,410', '6,801',
#        '38', '1,279', '146', '620', '155', '7,456', 'Leil Lowndes',
#        'Durga Bhagwat', '739', '130', 'Himani Verma Krishan Keshav',
#        'Sanjay Dixit', 'Devendra Kumar Singh', 'Prashant Bhushan',
#        'C.K. Takwani', 'Lexis', 'Challa Krishnaveer Abhishek',
#        'அம்மு இளையாள் ', 'ANANT PAI', 'Om Books Editorial Team',
#        'Ajay K Pandey', 'Andaleeb Wajid', 'விஜயமலர் Vijayamalar',
#        'श्री. दीपक करंजीकर. Deepak Karanjikar', 'Yogee',
#        'Arthur Conan Doyle', 'Shalu Sharma', 'Kalki Krishnamurthy',
#        'Paulo Coelho', 'Sashi Murali', 'James Allen', 'Datta Durjoy',
#        'Colleen Hoover', 'Vanisha Thandawan', 'Stuti Changle',
#        'Ruskin Bond', 'M.V. Kasi', 'Little Byte', 'உதய சந்திரிகா',
#        'Darius Foroux', 'J.K. Rowling', 'Saksham Garg', 'காதல் பிரியன்',
#        'Ramdhari Singh Dinkar', 'மிகி ரா', 'Vijayalakshmi Jagan',
#        'Akshat Gupta', '1,616', '9,784', '5,761', 'Map', 'Loose Leaf',
#        'INTERNATIONAL PUBLICATIONS', 'Vidya Chitr Prakashan',
#        'Rashid Yasin', 'JCB GROUP', 'EDITORIAL BOARD',
#        'INDIAN BOOK DEPOT (MAP HOUSE)', 'indian book depot',
#        'Hivex Publication', 'NANDA CHITRA PRAKASHAN', '105', '234', '24',
#        'Perfect Paperback', 'Prasad Manjeshwar', 'Gupta S. P.',
#        'Baron/Misra', 'Shree Balaji Tambe', '72', '1,654', '1,990', '650',
#        '1,298', 'Pandya', 'Inderbir Singh', 'MANTHAPPA M.', 'B Ramgopal',
#        'SSBCrack', 'B.M. Hegde',
#        'Xiaowen Wang Zachary Crees, Cassandra Fritz, Alonso Heudebert, Jonas Noé, Arvind Rengarajan',
#        '12,667', '83,161', '5,197', '1,824', '7,322', '239', '580',
#        'Adam Smith', 'A.P.J. Abdul Kalam', 'Yuval Noah Harari',
#        'Rabindranath Tagore', 'B.R.Ambedkar', 'Michelle Obama',
#        'Robert Greene', 'Benjamin Franklin', 'Dr. B R Ambedkar',
#        'Karl Marx', 'Rajiv Malhotra', 'Rukmini S', 'Amit Lodha',
#        'Sanjaya Baru', 'Barack Obama', 'Shashi Tharoor',
#        'Ramachandra Guha', 'Ravi Nair', 'Maloy Krishna Dhar',
#        'Caroline Criado Perez', 'Michael Bar-Zohar', 'Vikram Sampath',
#        'J Sai Deepak', 'Tim Marshall', 'Simon Sinek', 'Takeshi Obata',
#        'Vijay Gokhale', 'Various', 'Larry Collins', '14,356', '22,926',
#        '7,564', '10,983', '731', '185,555', '96', '91', '2,629', '989',
#        '2,376', '2,291', '1,045', '596', '2,309', '12,428', '2,332',
#        '345', '4,605', '575', '4,362', '4,461', '21,381', '19,115',
#        '3,459', '679', '2,071', '1,139', '95,859', '2,483', '672',
#        'Chitra Banerjee Divakaruni', 'ஆத்விகா பொம்மு (Aadvika pommu)',
#        'Saranya Umakanthan', 'Durjoy Datta', 'Emily Brontë', 'சர  ணிகா',
#        'Leonie Mack', 'உத்ரா சித்தார்த்', 'Arpit Vageria', '337',
#        '45,673', '8,848', '7,717', '39', '1,830', '151', '42', '145',
#        '211', '774', '2,839', '1,168', '80', '57', '588', '488', '47',
#        '306', '399', '12,179', '12', '1,788', '67', '27', '212',
#        'Mass Market Paperback', 'by DC Pandey (Author)',
#        'Gabrielle Zevin', '4,430', '6,570', '3,780', '3,186', '857',
#        '4,580', '2,580', '21,299', '36', '8,328', '1,077', '4,310',
#        '10,980', '7,831', '6,564', '4,159', '21,300', '3,899', '52,731',
#        '3,190', '94', '8,405', '23,518', '11,345', '124', '148', '338',
#        '3,627', '11,523', '1,017', '1,822', '641', 'Flexibound', '48,000',
#        '1,425', '1,179', '4,634', '1,907', '229', '609', '815', '5,119',
#        '743', '662', '3,239', '4,591', '992', '1,271', '2,114'],
#       dtype=object)

# %%
# Converting Book_no_of_reviews into integers
# handle such cases : x=['2300','2,000','abc']
def converting_to_int(i):
    if len(i.split(','))==1:
        try:
            i = int(i)
            return i
        except:
            i=0
            return i
    else:
        try:
            if len(i.split(','))==2:
                i = int(i.split(',')[0])*1000 + int(i.split(',')[1])
                return i
        except:
            i=0
            return i

# %%
final_result['book_no_of_reviews'].apply(converting_to_int)
# Out:
# 0     55325.0
# 1      2300.0
# 2     15471.0
# 3        55.0
# 4       326.0
#        ...
# 44        0.0
# 45        0.0
# 46        0.0
# 47        0.0
# 48        0.0
# Name: book_no_of_reviews, Length: 1451, dtype: float64
